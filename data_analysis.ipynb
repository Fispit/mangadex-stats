# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ast import literal_eval

# %%
manga_df=pd.read_pickle('./resources/manga_list.pckl')
manga_df
# Out:
#                                         id   type  \
# 0     5fb002de-95d1-4acb-a1ba-aabcfec814c3  manga
# 1     22290888-46b5-4f42-992c-5c2934fe91d1  manga
# 2     ab41d97a-0725-4f37-85db-da001d4ff0dc  manga
# 3     2c3cd370-04bd-4994-87dc-e54a4d80c4ec  manga
# 4     8325137c-32bf-464c-b716-b4c9b17c0002  manga
# ...                                    ...    ...
# 9995  b4320039-9b91-44a7-a60d-c7ba8c0684e7  manga
# 9996  5966861c-9e2c-41b8-a768-eba93b13b94f  manga
# 9997  aefff461-ce0f-4db2-b160-3eeb1b03f48e  manga
# 9998  ccd10c9b-1aad-437f-a888-d76d64525e67  manga
# 9999  56b91571-9a6f-429d-9a0d-f421eeed4c4d  manga
#
#                                     title orig_lang target_demographic  \
# 0                         Hell's Boat 136        ja             seinen
# 1      I’m a Human, but More So a Vampire        zh            shounen
# 2                          Chi no Wadachi        ja             seinen
# 3                      Natsume Yuujinchou        ja             shoujo
# ...

# %%
test=manga_df[manga_df['Supernatural']]
test
# Out:
#                                         id   type  \
# 3     2c3cd370-04bd-4994-87dc-e54a4d80c4ec  manga
# 12    a460ab18-22c1-47eb-a08a-9ee85fe37ec8  manga
# 15    5c9d1254-f074-4b5c-8795-6f0641b2597b  manga
# 23    fd824304-2f3f-44bc-a8ae-996f6ed1cacb  manga
# 30    b9ad64a8-bf30-445b-b97d-fe3fa39c2f22  manga
# ...                                    ...    ...
# 9973  795d4d43-677b-4751-8496-a28104882488  manga
# 9982  1ed17a14-6153-4279-8cf1-0a955bf60932  manga
# 9984  dde99b08-f53f-48db-aefb-c9617e53eaed  manga
# 9989  854cf05b-5366-48b4-84bd-0806aa0348f0  manga
# 9992  64b3118d-2ffd-4ebc-a4ca-aa4238a92544  manga
#
#                                                   title orig_lang  \
# 3                                    Natsume Yuujinchou        ja
# 12                      Bleach - Digital Colored Comics        ja
# 15                                     Girl and Science        zh
# 23    The Wooden-Mortared Kingdom - Garo 20th Annive...        ja
# ...
