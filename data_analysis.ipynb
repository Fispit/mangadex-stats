# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
manga_df=pd.read_csv('./resources/manga_list.csv')
tags_df=pd.read_csv('./resources/tag_list.csv')
manga_df
# Out:
#       Unnamed: 0                                    id   type  \
# 0              0  f2e91f99-6c3b-4a66-a3f7-9da13f68c416  manga
# 1              1  259dfd8a-f06a-4825-8fa6-a2dcd7274230  manga
# 2              2  9ecc98fc-07a0-4dc8-9216-9146948fb904  manga
# 3              3  4b0315ba-322f-434e-b5bd-89f1c001ebbd  manga
# 4              4  e4631dc7-87b9-4d6a-8b3b-5594664ecc27  manga
# ...          ...                                   ...    ...
# 9995        9995  22a86d7c-6827-402c-80af-dbdee3c6c6aa  manga
# 9996        9996  5eb514bc-bb37-4f37-a2e9-def530b08c29  manga
# 9997        9997  2c46f07f-7c9b-4ddb-b2dd-4cf8658f33b4  manga
# 9998        9998  f4676132-d3af-4027-8266-074c69035e98  manga
# 9999        9999  6db3d849-5e05-41bb-ab5c-561e2fef0ee4  manga
#
#                                                   title orig_lang  \
# 0                                         Ragna Crimson        ja
# 1                                      Yofukashi no Uta        ja
# ...
